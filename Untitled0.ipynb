# %% [markdown]
# <a href="https://colab.research.google.com/github/lyjiangli/jd/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/wzdnzd/aggregator.git
# Out:
# Cloning into 'aggregator'...
# remote: Enumerating objects: 3804, done.
# remote: Counting objects: 100% (10/10), done.
# remote: Compressing objects: 100% (9/9), done.
# remote: Total 3804 (delta 3), reused 1 (delta 1), pack-reused 3794 (from 4)
# Receiving objects: 100% (3804/3804), 725.94 MiB | 19.34 MiB/s, done.
# Resolving deltas: 100% (2232/2232), done.
# Updating files: 100% (509/509), done.

# %%
# %cd aggregator
# Out:
# /content/aggregator

# %%
# !pip install -r requirements.txt
# Out:
# ...
#   Preparing metadata (setup.py) ... done
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 88.2/88.2 kB 7.6 MB/s eta 0:00:00
# ...
#   Created wheel for fofa-hack: filename=fofa_hack-2.5.2-py3-none-any.whl size=31469 sha256=25917546c58e5c1702d51422223146fb70be7ab68ba1fffbf505c7fbd5c0972c
#   Stored in directory: /root/.cache/pip/wheels/be/24/dd/2a217b13b9f502c53f1c1212b2025abb144311371b77f848b3
# Successfully built fofa-hack
# ...

# %%
# !python -u subscribe/collect.py -s
# Out:
# 2025-05-31 03:42:52 collect.py [line:205] ERROR: cannot extract username and gist id due to invalid github gist link
# 2025-05-31 03:42:52 collect.py [line:68] INFO: start checking whether existing subscriptions have expired
# 2025-05-31 03:42:52 collect.py [line:110] INFO: load exists subscription finished, count: 0
# 2025-05-31 03:42:53 crawl.py [line:1434] INFO: [TelegramCrawl] starting crawl from telegram, channel: jichang_list, pages: 212
# 2025-05-31 03:42:53 crawl.py [line:1394] INFO: [AirPortCrawl] start collect airport, url: https://t.me/s/jichang_list?before=4231
# 2025-05-31 03:42:53 crawl.py [line:1394] INFO: [AirPortCrawl] start collect airport, url: https://t.me/s/jichang_list?before=4211
# 2025-05-31 03:42:53 crawl.py [line:1394] INFO: [AirPortCrawl] start collect airport, url: https://t.me/s/jichang_list?before=4191
# 2025-05-31 03:42:53 crawl.py [line:1394] INFO: [AirPortCrawl] start collect airport, url: https://t.me/s/jichang_list?before=4171
# ...

# %%
# !cat /content/aggregator/data/v2ray.txt
# Out:
# ...

# %%
from google.colab import files
files.download('/content/aggregator/data/v2ray.txt')
